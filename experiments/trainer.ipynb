# %%
import os
import torch.backends.cudnn as cudnn
import yaml
from train import train
from utils import AttrDict
import pandas as pd

# %%
cudnn.benchmark = True
cudnn.deterministic = False

# %%
def get_config(file_path):
    with open(file_path, 'r', encoding="utf8") as stream:
        opt = yaml.safe_load(stream)
    opt = AttrDict(opt)
    if opt.lang_char == 'None':
        characters = ''
        for data in opt['select_data'].split('-'):
            csv_path = os.path.join(opt['train_data'], data, 'labels.csv')
            df = pd.read_csv(csv_path, sep='^([^,]+),', engine='python', usecols=['filename', 'words'], keep_default_na=False)
            all_char = ''.join(df['words'])
            characters += ''.join(set(all_char))
        characters = sorted(set(characters))
        opt.character= ''.join(characters)
    else:
        opt.character = opt.number + opt.symbol + opt.lang_char
    os.makedirs(f'./saved_models/{opt.experiment_name}', exist_ok=True)
    return opt

# %%
opt = get_config("config_files/custom_data_train.yaml")

# %%
train(opt, amp=False)
# Out:
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: all_data
# opt.select_data: ['ru_train_filtered']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    all_data	 dataset: ru_train_filtered
# all_data/ru_train_filtered
# sub-directory:	/ru_train_filtered	 num samples: 765
# num total samples of ru_train_filtered: 765 x 1.0 (total_data_usage_ratio) = 765
# num samples of ru_train_filtered per batch: 64 x 1.0 (batch_ratio) = 64
# --------------------------------------------------------------------------------
# Total_batch_size: 64 = 64
# --------------------------------------------------------------------------------
# dataset_root:    all_data/ru_val	 dataset: /
# all_data/ru_val/
# sub-directory:	/.	 num samples: 214
# --------------------------------------------------------------------------------
# No Transformation module specified
# model input parameters 64 600 20 1 256 256 208 68 None VGG BiLSTM CTC
# loading pretrained model from C:/Users/Елизавета/Documents/ocr/EasyOCR/easyocr/model/cyrillic_g2.pth
# Model:
# DataParallel(
#   (module): Model(
#     (FeatureExtraction): VGG_FeatureExtractor(
#       (ConvNet): Sequential(
#         (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): ReLU(inplace=True)
#         (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (7): ReLU(inplace=True)
#         (8): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (9): ReLU(inplace=True)
#         (10): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (11): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (16): ReLU(inplace=True)
#         (17): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (18): Conv2d(256, 256, kernel_size=(2, 2), stride=(1, 1))
#         (19): ReLU(inplace=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#     (Prediction): Linear(in_features=256, out_features=208, bias=True)
#   )
# )
# Modules, Parameters
# module.FeatureExtraction.ConvNet.0.weight 288
# module.FeatureExtraction.ConvNet.0.bias 32
# module.FeatureExtraction.ConvNet.3.weight 18432
# module.FeatureExtraction.ConvNet.3.bias 64
# module.FeatureExtraction.ConvNet.6.weight 73728
# module.FeatureExtraction.ConvNet.6.bias 128
# module.FeatureExtraction.ConvNet.8.weight 147456
# module.FeatureExtraction.ConvNet.8.bias 128
# module.FeatureExtraction.ConvNet.11.weight 294912
# module.FeatureExtraction.ConvNet.12.weight 256
# module.FeatureExtraction.ConvNet.12.bias 256
# module.FeatureExtraction.ConvNet.14.weight 589824
# module.FeatureExtraction.ConvNet.15.weight 256
# module.FeatureExtraction.ConvNet.15.bias 256
# module.FeatureExtraction.ConvNet.18.weight 262144
# module.FeatureExtraction.ConvNet.18.bias 256
# module.SequenceModeling.0.rnn.weight_ih_l0 262144
# module.SequenceModeling.0.rnn.weight_hh_l0 262144
# module.SequenceModeling.0.rnn.bias_ih_l0 1024
# module.SequenceModeling.0.rnn.bias_hh_l0 1024
# module.SequenceModeling.0.rnn.weight_ih_l0_reverse 262144
# module.SequenceModeling.0.rnn.weight_hh_l0_reverse 262144
# module.SequenceModeling.0.rnn.bias_ih_l0_reverse 1024
# module.SequenceModeling.0.rnn.bias_hh_l0_reverse 1024
# module.SequenceModeling.0.linear.weight 131072
# module.SequenceModeling.0.linear.bias 256
# module.SequenceModeling.1.rnn.weight_ih_l0 262144
# module.SequenceModeling.1.rnn.weight_hh_l0 262144
# module.SequenceModeling.1.rnn.bias_ih_l0 1024
# module.SequenceModeling.1.rnn.bias_hh_l0 1024
# module.SequenceModeling.1.rnn.weight_ih_l0_reverse 262144
# module.SequenceModeling.1.rnn.weight_hh_l0_reverse 262144
# module.SequenceModeling.1.rnn.bias_ih_l0_reverse 1024
# module.SequenceModeling.1.rnn.bias_hh_l0_reverse 1024
# module.SequenceModeling.1.linear.weight 131072
# module.SequenceModeling.1.linear.bias 256
# module.Prediction.weight 53248
# module.Prediction.bias 208
# Total Trainable Params: 3809872
# Trainable params num :  3809872
# Optimizer:
# Adadelta (
# Parameter Group 0
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     lr: 1.0
#     maximize: False
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# number: 0123456789
# symbol: !"#$%&'()*+,-./:;<=>?@[\]№_`{|}~ €₽
# lang_char: ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyzАБВГДЕЁЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯабвгдеёжзийклмнопрстуфхцчшщъыьэюяЂђЃѓЄєІіЇїЈјЉљЊњЋћЌќЎўЏџҐґҒғҚқҮүҲҳҶҷӀӏӢӣӨөӮӯ
# experiment_name: ru_filtered
# train_data: all_data
# valid_data: all_data/ru_val
# manualSeed: 1111
# workers: 6
# batch_size: 64
# num_iter: 30000
# valInterval: 200
# saved_model: C:/Users/Елизавета/Documents/ocr/EasyOCR/easyocr/model/cyrillic_g2.pth
# FT: True
# optim: False
# lr: 1.0
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# select_data: ['ru_train_filtered']
# batch_ratio: ['1']
# total_data_usage_ratio: 1.0
# batch_max_length: 68
# imgH: 64
# imgW: 600
# rgb: False
# contrast_adjust: 0.0
# sensitive: True
# PAD: True
# data_filtering_off: False
# Transformation: None
# FeatureExtraction: VGG
# SequenceModeling: BiLSTM
# Prediction: CTC
# num_fiducial: 20
# input_channel: 1
# output_channel: 256
# hidden_size: 256
# decode: greedy
# new_prediction: False
# freeze_FeatureFxtraction: False
# freeze_SequenceModeling: False
# character: 0123456789!"#$%&'()*+,-./:;<=>?@[\]№_`{|}~ €₽ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyzАБВГДЕЁЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯабвгдеёжзийклмнопрстуфхцчшщъыьэюяЂђЃѓЄєІіЇїЈјЉљЊњЋћЌќЎўЏџҐґҒғҚқҮүҲҳҶҷӀӏӢӣӨөӮӯ
# num_class: 208
# ---------------------------------------
#
# training time:  116.06608557701111
# [200/30000] Train loss: 0.36958, Valid loss: 0.68427, Elapsed_time: 116.06609
# Current_accuracy : 18.224, Current_norm_ED  : 0.8661
# Best_accuracy    : 18.224, Best_norm_ED     : 0.8661
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "ссия, 440031,пензенская обл, г. пенза, ул. курская " | ссия, 440031, пензенская обл, г. пенза, ул курская | 0.0000	False
# более 75%.                | более 75%.                | 0.1376	True
# --------------------------------------------------------------------------------
# validation time:  10.333314418792725
# training time:  117.64102125167847
# [400/30000] Train loss: 0.01683, Valid loss: 0.78797, Elapsed_time: 244.04042
# Current_accuracy : 21.963, Current_norm_ED  : 0.8674
# Best_accuracy    : 21.963, Best_norm_ED     : 0.8674
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "дата изготовления (число, месяц, год) и масса нетто " | дата кагртовления (число; мвсяц: год) и мвсса нетто " | 0.0007	False
# "62,0 мг "                | 62,0 мг                   | 0.3258	False
# --------------------------------------------------------------------------------
# validation time:  9.06457233428955
# training time:  119.43651223182678
# [600/30000] Train loss: 0.00241, Valid loss: 0.87880, Elapsed_time: 372.54151
# Current_accuracy : 23.364, Current_norm_ED  : 0.8717
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8717
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# изготовлен из концентрированного со | изготовлен из концентрированного со | 0.0532	True
# ложке (10 г)              | ложке (10 г )             | 0.0254	False
# --------------------------------------------------------------------------------
# validation time:  8.739335536956787
# training time:  110.06569600105286
# [800/30000] Train loss: 0.00100, Valid loss: 0.91127, Elapsed_time: 491.34654
# Current_accuracy : 23.364, Current_norm_ED  : 0.8702
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8717
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# масса нетто без глазури   | масса нетто без г лаяури: | 0.2844	False
# "олоко питьевое пастеризованное, " | олоко питьевое пастеризованное, " | 0.1737	False
# --------------------------------------------------------------------------------
# validation time:  8.6050865650177
# training time:  115.54052066802979
# [1000/30000] Train loss: 0.00058, Valid loss: 0.94951, Elapsed_time: 615.49214
# Current_accuracy : 23.364, Current_norm_ED  : 0.8721
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8721
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# дата производства см. на упаковке | дата производства см. на упаковке | 0.1392	True
# ел./факс: +7 (48439) 3-70-14 | "л./факс: +7 (48439) 3-70-14 | 0.1877	False
# --------------------------------------------------------------------------------
# validation time:  8.691220998764038
# training time:  114.79812455177307
# [1200/30000] Train loss: 0.00042, Valid loss: 0.98110, Elapsed_time: 738.98149
# Current_accuracy : 22.897, Current_norm_ED  : 0.8697
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8721
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# и относительной влажности воз | и относиттельнои ваажности воз | 0.0806	False
# исо 22000                 | "со тооо                  | 0.6276	False
# --------------------------------------------------------------------------------
# validation time:  8.957035303115845
# training time:  110.29145336151123
# [1400/30000] Train loss: 0.00032, Valid loss: 1.00049, Elapsed_time: 858.22998
# Current_accuracy : 22.430, Current_norm_ED  : 0.8719
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8721
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# изгото                    | "узкой                    | 0.3525	False
# также                     | таюе                      | 0.8277	False
# --------------------------------------------------------------------------------
# validation time:  9.43921971321106
# training time:  114.91235518455505
# [1600/30000] Train loss: 0.00028, Valid loss: 1.00315, Elapsed_time: 982.58155
# Current_accuracy : 22.897, Current_norm_ED  : 0.8713
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8721
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# щевая ценность (содержание в 100 г продукта) | щевая ценность (содержание в 100 г продукта) | 0.0526	True
# "углеводы 56,5 "          | углеводы - 56,5 г.        | 0.0350	False
# --------------------------------------------------------------------------------
# validation time:  9.723728656768799
# training time:  115.21537327766418
# [1800/30000] Train loss: 0.00022, Valid loss: 1.02326, Elapsed_time: 1107.52066
# Current_accuracy : 22.430, Current_norm_ED  : 0.8673
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8721
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 0г                        | 0 г                       | 0.9455	False
# "хар, экстракт ванили); загустители-кукурузный кра " | хар, экстракт ванили): загустители кукурузный кра | 0.0198	False
# --------------------------------------------------------------------------------
# validation time:  10.244758129119873
# training time:  109.76071667671204
# [2000/30000] Train loss: 0.00019, Valid loss: 1.02890, Elapsed_time: 1227.52613
# Current_accuracy : 22.430, Current_norm_ED  : 0.8671
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8721
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# пригарина екатерина       | пригарина екатерина       | 0.7793	True
# сливочный                 | ""сливочный>"             | 0.4002	False
# --------------------------------------------------------------------------------
# validation time:  8.571961402893066
# training time:  112.34858870506287
# [2200/30000] Train loss: 0.00017, Valid loss: 1.02947, Elapsed_time: 1348.44668
# Current_accuracy : 22.430, Current_norm_ED  : 0.8707
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8721
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# уп мичурина 7             | уп. мичурина. 7           | 0.4784	False
# без                       | бел                       | 0.2202	False
# --------------------------------------------------------------------------------
# validation time:  9.264070987701416
# training time:  113.87847876548767
# [2400/30000] Train loss: 0.00015, Valid loss: 1.04631, Elapsed_time: 1471.58923
# Current_accuracy : 22.897, Current_norm_ED  : 0.8693
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8721
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# балаларды                 | балаларды                 | 0.8513	True
# номер партии              | номер партии/             | 0.6670	False
# --------------------------------------------------------------------------------
# validation time:  9.312762022018433
# training time:  110.53699517250061
# [2600/30000] Train loss: 0.00013, Valid loss: 1.05964, Elapsed_time: 1591.43899
# Current_accuracy : 22.430, Current_norm_ED  : 0.8708
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8721
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "олоко питьевое пастеризованное, " | олоко питьевое пастеризованное, " | 0.1602	False
# одинцовский р-н ; п часцы; стр 3 | "одинцовский рен, пчасцы, стр.з " | 0.0894	False
# --------------------------------------------------------------------------------
# validation time:  8.612586259841919
# training time:  115.33559656143188
# [2800/30000] Train loss: 0.00012, Valid loss: 1.06858, Elapsed_time: 1715.38717
# Current_accuracy : 22.430, Current_norm_ED  : 0.8712
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8721
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# дата производства см. на упаковке | дата производства см. на упаковке | 0.1663	True
# "ао новая ""сто "         | воновая сто               | 0.1035	False
# --------------------------------------------------------------------------------
# validation time:  9.520506381988525
# training time:  115.40103697776794
# [3000/30000] Train loss: 0.00011, Valid loss: 1.06302, Elapsed_time: 1840.30871
# Current_accuracy : 22.897, Current_norm_ED  : 0.8708
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8721
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "ная; д. 10, корп: 1, оф.425, тел: +7 (812) 346-60-02.гост р 52686 " | ная, д, 10, корп 1,оф. 425,тел. +7 (812) 346-60-02 гостр 52686 | 0.0006	False
# аблице приведены информацнонные (расчетные) пок: | "аблице приведены нинформационные (расчетнне пок | 0.1120	False
# --------------------------------------------------------------------------------
# validation time:  8.577414989471436
# training time:  107.96601438522339
# [3200/30000] Train loss: 0.00041, Valid loss: 1.07088, Elapsed_time: 1956.85314
# Current_accuracy : 21.963, Current_norm_ED  : 0.8696
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8721
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "0,11 мг "                | 0,11мг "                  | 0.5060	False
# минеральные ма            | минеральные ма            | 0.2154	True
# --------------------------------------------------------------------------------
# validation time:  8.657373905181885
# training time:  112.68281149864197
# [3400/30000] Train loss: 0.00017, Valid loss: 1.03947, Elapsed_time: 2078.19433
# Current_accuracy : 21.963, Current_norm_ED  : 0.8713
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8721
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# а продукт может содержать молоко; хранит | а. продукт может содержать молоко хранит | 0.0445	False
# "изготовитель: ооо ""нестле россия"" россия  115054 м " | зготовитель: оо нестле россия , россия 115054, м | 0.0186	False
# --------------------------------------------------------------------------------
# validation time:  9.663678169250488
# training time:  112.92880654335022
# [3600/30000] Train loss: 0.00011, Valid loss: 1.05863, Elapsed_time: 2200.78681
# Current_accuracy : 21.963, Current_norm_ED  : 0.8720
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8721
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# акция                     | акция                     | 0.9988	True
# температуре от 0 с до 25 с и относительной влажности воздуха | тенпературе от 0 %с до 25 "с и относительной влажности воздуха | 0.0176	False
# --------------------------------------------------------------------------------
# validation time:  9.396475315093994
# training time:  108.62476062774658
# [3800/30000] Train loss: 0.00010, Valid loss: 1.07900, Elapsed_time: 2318.80905
# Current_accuracy : 21.495, Current_norm_ED  : 0.8717
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8721
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# х для продукции из натурального сырья. хран | их для продукции из натурального сырья. хран | 0.3964	False
# температуре от 0 с до 25 с и относительной влажности воздуха | тенпературе от 0 %с до 25 "с и относительной влажности воздуха | 0.0151	False
# --------------------------------------------------------------------------------
# validation time:  10.409075736999512
# training time:  117.0996766090393
# [4000/30000] Train loss: 0.00009, Valid loss: 1.11175, Elapsed_time: 2446.31780
# Current_accuracy : 21.495, Current_norm_ED  : 0.8708
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8721
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 25с и относительной влажностии воздух | 5'с и опносипельной влажности воздук" | 0.0226	False
# сильного нагрева или охлаждени | сильного нагрева или охлаждени | 0.2361	True
# --------------------------------------------------------------------------------
# validation time:  10.511244058609009
# training time:  113.22380638122559
# [4200/30000] Train loss: 0.00008, Valid loss: 1.09477, Elapsed_time: 2570.05285
# Current_accuracy : 21.963, Current_norm_ED  : 0.8728
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8728
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# тав свинина вода филе грулок кур б | тав: свинина вода филе грулок кур 6 " | 0.2377	False
# олее 30 мг на 100 мл напитка. не рокомендется употре | "яье э0 и ка 100 мл иапитъа. не рехонендуетья увотае | 0.0002	False
# --------------------------------------------------------------------------------
# validation time:  8.539379358291626
# training time:  112.53063917160034
# [4400/30000] Train loss: 0.00007, Valid loss: 1.10784, Elapsed_time: 2691.12287
# Current_accuracy : 21.963, Current_norm_ED  : 0.8729
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8729
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# аровая камедь; регулятор кислотности-лимонная к: | "ровая камедь; регулятор кислотности лимонная к" | 0.0430	False
# скачивайте                | скачивайте                | 0.5927	True
# --------------------------------------------------------------------------------
# validation time:  9.592142581939697
# training time:  118.92333102226257
# [4600/30000] Train loss: 0.00007, Valid loss: 1.10735, Elapsed_time: 2819.63834
# Current_accuracy : 21.963, Current_norm_ED  : 0.8737
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8737
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ит источник фенилаланина. натурального ко | "ит источний фенилаланина. натуряльного " | 0.0034	False
# масса нетто 300 г.        | масса нетто 300 г.        | 0.1305	False
# --------------------------------------------------------------------------------
# validation time:  8.73563528060913
# training time:  116.77931809425354
# [4800/30000] Train loss: 0.00006, Valid loss: 1.10159, Elapsed_time: 2945.15330
# Current_accuracy : 21.963, Current_norm_ED  : 0.8728
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8737
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# с наполнителем            | с наполнителем            | 0.5505	True
# температуре не выше минус 18 с не более 10 суток бе | "млературе не выше минус 18-с не боляя 10 суос к" | 0.0107	False
# --------------------------------------------------------------------------------
# validation time:  9.212723016738892
# training time:  109.32999181747437
# [5000/30000] Train loss: 0.00006, Valid loss: 1.09719, Elapsed_time: 3063.69601
# Current_accuracy : 21.963, Current_norm_ED  : 0.8723
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8737
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# олее 30 мг на 100 мл напитка. не рокомендется употре | "яье э0 и  ка 100 мл иапитъа. не рехонендуетья увотае | 0.0001	False
# тегории г. изготовлено по ту 9214-276-01597945-20( | тегории изготовлено по 7у 9214-276-01597945-20 " | 0.0150	False
# --------------------------------------------------------------------------------
# validation time:  9.460778951644897
# training time:  113.7025842666626
# [5200/30000] Train loss: 0.00005, Valid loss: 1.13666, Elapsed_time: 3186.85937
# Current_accuracy : 21.495, Current_norm_ED  : 0.8713
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8737
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ясной продукт категории   | ясной продукт категории   | 0.4590	True
# "ооо тпп вкусные консервы, 143041,  " | "боо жтп вкусные консервы, 1д0401" | 0.0148	False
# --------------------------------------------------------------------------------
# validation time:  10.217187404632568
# training time:  113.35737013816833
# [5400/30000] Train loss: 0.00005, Valid loss: 1.10726, Elapsed_time: 3310.43393
# Current_accuracy : 21.963, Current_norm_ED  : 0.8721
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8737
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# " сти три-фосфат натрия, усипитель в " | сти три-фосфат натрия, усилитель в | 0.4711	False
# дату изготовления смотри на к | дату изготовления смотри на ке: | 0.0680	False
# --------------------------------------------------------------------------------
# validation time:  8.597457647323608
# training time:  109.0924563407898
# [5600/30000] Train loss: 0.00005, Valid loss: 1.13110, Elapsed_time: 3428.12384
# Current_accuracy : 21.963, Current_norm_ED  : 0.8728
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8737
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "и масла растительные, вода, соль, сахар, " | "1 масла растптвпыые, вола, соль, с хлр  | 0.0031	False
# консерванты:              | консерванты:              | 0.4419	True
# --------------------------------------------------------------------------------
# validation time:  9.059794425964355
# training time:  112.74300909042358
# [5800/30000] Train loss: 0.00005, Valid loss: 1.12095, Elapsed_time: 3549.92665
# Current_accuracy : 22.430, Current_norm_ED  : 0.8736
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8737
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# дата производства см. на упаковке | дата производства см. на упаковке | 0.1818	True
# хранить в холодильнике    | кранить в холодильнике.   | 0.2345	False
# --------------------------------------------------------------------------------
# validation time:  9.870070457458496
# training time:  113.09452223777771
# [6000/30000] Train loss: 0.00005, Valid loss: 1.09894, Elapsed_time: 3672.89124
# Current_accuracy : 22.430, Current_norm_ED  : 0.8728
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8737
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "нергетическая ценность: 692,6 ккал/ 2897,2 кд " | нергетическая ценность: 692,6 ккал 2897.2 кл | 0.1880	False
# тегории г. изготовлено по ту 9214-276-01597945-20( | тегории изготовлено по 7у 9214-276-01597945-20 " | 0.0164	False
# --------------------------------------------------------------------------------
# validation time:  8.871680736541748
# training time:  109.52373814582825
# [6200/30000] Train loss: 0.00004, Valid loss: 1.13897, Elapsed_time: 3791.28666
# Current_accuracy : 21.963, Current_norm_ED  : 0.8705
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8737
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "изготовитель: ооо ""нестле россия"" россия  115054 м " | зготовитель: ооо нестле россия , россия 115054, м | 0.0179	False
# срок годности 9 месяцев   | срок годности 9 месяцев   | 0.7063	True
# --------------------------------------------------------------------------------
# validation time:  9.888582706451416
# training time:  114.02940630912781
# [6400/30000] Train loss: 0.00004, Valid loss: 1.11816, Elapsed_time: 3915.20465
# Current_accuracy : 21.963, Current_norm_ED  : 0.8719
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8737
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# минеральные ма            | минеральные ма            | 0.3039	True
# мираторг                  | мираторг                  | 0.9677	True
# --------------------------------------------------------------------------------
# validation time:  9.022337198257446
# training time:  113.89947819709778
# [6600/30000] Train loss: 0.00004, Valid loss: 1.12366, Elapsed_time: 4038.12646
# Current_accuracy : 21.963, Current_norm_ED  : 0.8705
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8737
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "дата изготовления (число, месяц, год) и масса нетто " | дата кэгртовления (число; мвсяц: год) и мвсса нетто " | 0.0185	False
# годен до:                 | годендо:                  | 0.2578	False
# --------------------------------------------------------------------------------
# validation time:  9.471510171890259
# training time:  109.1805305480957
# [6800/30000] Train loss: 0.00004, Valid loss: 1.12022, Elapsed_time: 4156.77850
# Current_accuracy : 21.963, Current_norm_ED  : 0.8724
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8737
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "ссия, 440031,пензенская обл, г. пенза, ул. курская " | ссия, 440031, пензенская обл, г пенза, ул курская | 0.0678	False
# сухое цельное молоко какао масло: эмулыгаторы | сухое цельное молоко; какао масло эмульгаторы" | 0.3152	False
# --------------------------------------------------------------------------------
# validation time:  8.750555038452148
# training time:  113.55013751983643
# [7000/30000] Train loss: 0.00004, Valid loss: 1.14123, Elapsed_time: 4279.07920
# Current_accuracy : 21.963, Current_norm_ED  : 0.8743
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# температуре не выше минус 18 с не более 10 суток бе | "млературе не выше минус 18-с не боляя 10 суос к" | 0.0205	False
# доля фруктового сока - 50%. | доля фруктового сока - 50%. | 0.1819	True
# --------------------------------------------------------------------------------
# validation time:  9.758830547332764
# training time:  113.80463361740112
# [7200/30000] Train loss: 0.00004, Valid loss: 1.12444, Elapsed_time: 4402.64266
# Current_accuracy : 21.963, Current_norm_ED  : 0.8728
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# " тертое; сахар; какао масло, молочный жир; эмульг " | ) тертое, сахар; какао масло, молочный жир, эмуль" | 0.0144	False
# изготовлено по заказу     | изготовлено по заказу     | 0.6872	True
# --------------------------------------------------------------------------------
# validation time:  9.172687768936157
# training time:  108.63235688209534
# [7400/30000] Train loss: 0.00004, Valid loss: 1.13687, Elapsed_time: 4520.44771
# Current_accuracy : 21.963, Current_norm_ED  : 0.8725
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "новый арбат дом 15,стр. " | . новый арбат аом 15,стр. 1." | 0.1427	False
# "сои, кунжута, горчицы. пищевая ценность: бел  " | "соц, кунжута, горчицы: пнщевая ценность: 6) | 0.0261	False
# --------------------------------------------------------------------------------
# validation time:  10.182111978530884
# training time:  113.74148941040039
# [7600/30000] Train loss: 0.00003, Valid loss: 1.14668, Elapsed_time: 4644.37131
# Current_accuracy : 21.495, Current_norm_ED  : 0.8718
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "л. казинца, 524-22. тел.: +375 44 7888 " | "л. казинца, 2а- 22. "тел.:: +375 44 7888 " | 0.0086	False
# "белки-21,9г, жиры-21,2 г. " | белки-21,9 г жиры-21.2 г  | 0.0183	False
# --------------------------------------------------------------------------------
# validation time:  9.078007698059082
# training time:  112.8844883441925
# [7800/30000] Train loss: 0.00003, Valid loss: 1.13250, Elapsed_time: 4766.33480
# Current_accuracy : 21.963, Current_norm_ED  : 0.8724
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# уп мичурина 7             | уп. мичурина. 7           | 0.5836	False
# "хар, экстракт ванили); загустители-кукурузный кра " | хар, экстракт ванили): загустители кукурузный кра | 0.0424	False
# --------------------------------------------------------------------------------
# validation time:  8.375521659851074
# training time:  106.95163345336914
# [8000/30000] Train loss: 0.00003, Valid loss: 1.15182, Elapsed_time: 4881.66196
# Current_accuracy : 22.430, Current_norm_ED  : 0.8718
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "0,11 мг "                | 0,11мг "                  | 0.6364	False
# 'ергетическая ценность (калорийность) 100 г продукта: 119 кдж (28 к | ургетроьай ценость (калориноть 100 г продукта:  клж (28 " | 0.0001	False
# --------------------------------------------------------------------------------
# validation time:  9.092789649963379
# training time:  111.8762571811676
# [8200/30000] Train loss: 0.00003, Valid loss: 1.16734, Elapsed_time: 5002.63100
# Current_accuracy : 21.963, Current_norm_ED  : 0.8688
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# также                     | таюе                      | 0.8673	False
# циро                      | циро                      | 0.9994	True
# --------------------------------------------------------------------------------
# validation time:  9.594115972518921
# training time:  114.35835313796997
# [8400/30000] Train loss: 0.00003, Valid loss: 1.16039, Elapsed_time: 5126.58347
# Current_accuracy : 21.963, Current_norm_ED  : 0.8709
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# консервы мясные кусковые стерилизованные | "онсервы мясные кусковые стерилизованные | 0.0682	False
# "6,5г "                   | 6,5 г"                    | 0.5416	False
# --------------------------------------------------------------------------------
# validation time:  10.215681791305542
# training time:  109.40768551826477
# [8600/30000] Train loss: 0.00003, Valid loss: 1.16088, Elapsed_time: 5246.20784
# Current_accuracy : 21.963, Current_norm_ED  : 0.8717
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# по россии звонок бесплатны | по россии звонок бесплатный | 0.8382	False
# родукта на 1 л воды: варить в течение 8 минут | родукта на 1 л воды: варить в течение 8 минутпо | 0.3525	False
# --------------------------------------------------------------------------------
# validation time:  8.863067865371704
# training time:  112.99921917915344
# [8800/30000] Train loss: 0.00003, Valid loss: 1.16853, Elapsed_time: 5368.07012
# Current_accuracy : 21.963, Current_norm_ED  : 0.8722
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# консерванты:              | консерванты:              | 0.4403	True
# "тыква с семенами тыквы"" без са " | "тыква с семенами тыквь безс  | 0.3050	False
# --------------------------------------------------------------------------------
# validation time:  8.617645978927612
# training time:  110.60566568374634
# [9000/30000] Train loss: 0.00003, Valid loss: 1.17748, Elapsed_time: 5487.29343
# Current_accuracy : 22.430, Current_norm_ED  : 0.8710
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "новый арбат дом 15,стр. " | . новый арбат аом 15,стр. 1." | 0.1473	False
# желез                     | еламо                     | 0.3489	False
# --------------------------------------------------------------------------------
# validation time:  8.970300912857056
# training time:  105.96513295173645
# [9200/30000] Train loss: 0.00003, Valid loss: 1.18053, Elapsed_time: 5602.22987
# Current_accuracy : 22.430, Current_norm_ED  : 0.8726
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# государственно            | госдерствснне             | 0.1407	False
# "шкой (сахар, кусочки молочного шоколада (масло кака " | "шкой (сахар кусочки молочного шоколада (масло кака | 0.1301	False
# --------------------------------------------------------------------------------
# validation time:  9.667150735855103
# training time:  110.31187176704407
# [9400/30000] Train loss: 0.00003, Valid loss: 1.15403, Elapsed_time: 5722.20889
# Current_accuracy : 21.963, Current_norm_ED  : 0.8706
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# не содержит гмо!          | не содержитгмо            | 0.6409	False
# пригарина екатерина       | пригарина екатерина       | 0.6480	True
# --------------------------------------------------------------------------------
# validation time:  8.76997995376587
# training time:  110.87809824943542
# [9600/30000] Train loss: 0.00003, Valid loss: 1.17699, Elapsed_time: 5841.85697
# Current_accuracy : 21.495, Current_norm_ED  : 0.8717
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# начения) : белки 15.8 г жиры 2.5 г | "начения): белки- 15,8 г: жирс-евл" | 0.0486	False
# мононенасыщенные          | мононенасыщенные          | 0.6376	True
# --------------------------------------------------------------------------------
# validation time:  8.195023775100708
# training time:  106.23601937294006
# [9800/30000] Train loss: 0.00003, Valid loss: 1.16838, Elapsed_time: 5956.28801
# Current_accuracy : 22.430, Current_norm_ED  : 0.8708
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# аровая камедь; регулятор кислотности-лимонная к: | "ровая камедь; регулятор кислотности лимонная к" | 0.0627	False
# мл                        | мл                        | 0.9996	True
# --------------------------------------------------------------------------------
# validation time:  8.513648986816406
# training time:  110.10811448097229
# [10000/30000] Train loss: 0.00003, Valid loss: 1.17941, Elapsed_time: 6074.90978
# Current_accuracy : 21.963, Current_norm_ED  : 0.8703
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "дата изготовления (число, месяц, год) и масса нетто " | дата кэготовления (число; мвсяц: год) и мвсса нетто " | 0.0269	False
# "и масла растительные, вода, соль, сахар, " | "1 масла растптвпыые, вола, соль, свхлр  | 0.0037	False
# --------------------------------------------------------------------------------
# validation time:  9.91408109664917
# training time:  109.20670557022095
# [10200/30000] Train loss: 0.00002, Valid loss: 1.19355, Elapsed_time: 6194.03056
# Current_accuracy : 22.430, Current_norm_ED  : 0.8715
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "россия, воронежская обл., бутурлиновский р-н. р.п Нижн  " | россия воронежская обл. бутурлиновский р,а рл нн " | 0.0135	False
# выращено в брянской области | выращено в брянской области | 0.6301	True
# --------------------------------------------------------------------------------
# validation time:  8.129775047302246
# training time:  105.23325991630554
# [10400/30000] Train loss: 0.00002, Valid loss: 1.17804, Elapsed_time: 6307.39360
# Current_accuracy : 22.430, Current_norm_ED  : 0.8721
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# татьяна наконечная        | татьна наконечная         | 0.7735	False
# "ства (изготовления): число, месяц, год-см " | "тва (иэготовления) число месяц год-см | 0.0612	False
# --------------------------------------------------------------------------------
# validation time:  8.143029928207397
# training time:  109.41598296165466
# [10600/30000] Train loss: 0.00002, Valid loss: 1.20311, Elapsed_time: 6424.95261
# Current_accuracy : 22.430, Current_norm_ED  : 0.8714
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "углеводы 56,5 "          | углеводы - 56,5 г.        | 0.1117	False
# государственно            | госдерственне             | 0.2038	False
# --------------------------------------------------------------------------------
# validation time:  8.885241985321045
# training time:  109.69611382484436
# [10800/30000] Train loss: 0.00002, Valid loss: 1.20022, Elapsed_time: 6543.53397
# Current_accuracy : 22.430, Current_norm_ED  : 0.8722
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# аблице приведены информацнонные (расчетные) пок: | "аблице приведены ниформационные (расчетнне пок | 0.0921	False
# "натрия, "                | натрия,                   | 0.7853	False
# --------------------------------------------------------------------------------
# validation time:  8.343703985214233
# training time:  104.97251224517822
# [11000/30000] Train loss: 0.00002, Valid loss: 1.16859, Elapsed_time: 6656.85018
# Current_accuracy : 21.963, Current_norm_ED  : 0.8700
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# ...
# --------------------------------------------------------------------------------
# validation time:  8.415343046188354
# training time:  106.73794150352478
# [26000/30000] Train loss: 0.00001, Valid loss: 1.25134, Elapsed_time: 15565.82923
# Current_accuracy : 21.963, Current_norm_ED  : 0.8693
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# продукт повторно не замораживать | продукт повторно не замораживать | 0.6579	True
# "и масла растительные, вода, соль, сахар, " | "1 масла растптвпыые, вола, соль, свхлр  | 0.0122	False
# --------------------------------------------------------------------------------
# validation time:  8.868534088134766
# training time:  111.7232506275177
# [26200/30000] Train loss: 0.00001, Valid loss: 1.27261, Elapsed_time: 15686.42101
# Current_accuracy : 21.963, Current_norm_ED  : 0.8706
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "ао новая ""сто "         | воновая сто               | 0.2360	False
# "ощенной пшеницы, сол  "  | ощенной пшеницы, сол      | 0.5530	False
# --------------------------------------------------------------------------------
# validation time:  10.093802452087402
# training time:  111.58671712875366
# [26400/30000] Train loss: 0.00001, Valid loss: 1.25577, Elapsed_time: 15808.10253
# Current_accuracy : 22.430, Current_norm_ED  : 0.8706
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "санкт-петербург, ул. савушкина, 112 " | г: санкт-петербург ул: савушкина 112" | 0.1250	False
# мальтодекстрин            | мальтодекстрин;           | 0.8411	False
# --------------------------------------------------------------------------------
# validation time:  9.27346658706665
# training time:  106.77685642242432
# [26600/30000] Train loss: 0.00001, Valid loss: 1.23735, Elapsed_time: 15924.15386
# Current_accuracy : 21.963, Current_norm_ED  : 0.8708
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "натрия, "                | натрия,                   | 0.7751	False
# "2 г, углеводы - 4,5 г, калорийнос " | е г;, углеводы 45 г, калорийнос | 0.0142	False
# --------------------------------------------------------------------------------
# validation time:  8.670644044876099
# training time:  111.67434310913086
# [26800/30000] Train loss: 0.00001, Valid loss: 1.27249, Elapsed_time: 16044.49884
# Current_accuracy : 21.963, Current_norm_ED  : 0.8707
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 0г                        | 0 г                       | 0.9246	False
# 25с и относительной влажностии воздух | 5'с и опносительной влажности возду" | 0.1488	False
# --------------------------------------------------------------------------------
# validation time:  8.622246026992798
# training time:  111.51344895362854
# [27000/30000] Train loss: 0.00001, Valid loss: 1.28540, Elapsed_time: 16164.63454
# Current_accuracy : 21.495, Current_norm_ED  : 0.8703
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# газированный              | газированный              | 0.7946	True
# без гмо                   | без тлмо                  | 0.2208	False
# --------------------------------------------------------------------------------
# validation time:  8.39180850982666
# training time:  106.97030782699585
# [27200/30000] Train loss: 0.00001, Valid loss: 1.25047, Elapsed_time: 16279.99765
# Current_accuracy : 21.963, Current_norm_ED  : 0.8705
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# сыро-мороженых            | сыро-мороженых            | 0.1942	True
# уп мичурина 7             | уп. мичурина. 7           | 0.6323	False
# --------------------------------------------------------------------------------
# validation time:  9.975770711898804
# training time:  111.60215616226196
# [27400/30000] Train loss: 0.00001, Valid loss: 1.26337, Elapsed_time: 16401.57558
# Current_accuracy : 21.963, Current_norm_ED  : 0.8697
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# мл                        | мл                        | 0.9999	True
# и относительной влажности воз | и относительнои ваажности воз | 0.0721	False
# --------------------------------------------------------------------------------
# validation time:  8.220472812652588
# training time:  111.76327109336853
# [27600/30000] Train loss: 0.00001, Valid loss: 1.24688, Elapsed_time: 16521.55932
# Current_accuracy : 21.963, Current_norm_ED  : 0.8706
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# м                         | "м                        | 0.8462	False
# "новый арбат дом 15,стр. " | . новый арбат аом 15,стр. 1." | 0.1608	False
# --------------------------------------------------------------------------------
# validation time:  8.68469500541687
# training time:  106.84627223014832
# [27800/30000] Train loss: 0.00001, Valid loss: 1.26518, Elapsed_time: 16637.09029
# Current_accuracy : 21.495, Current_norm_ED  : 0.8703
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# в какао масле             | в какао масле             | 0.4035	True
# мононенасыщенные          | мононенасыщенные          | 0.5897	True
# --------------------------------------------------------------------------------
# validation time:  8.697120904922485
# training time:  111.48762607574463
# [28000/30000] Train loss: 0.00001, Valid loss: 1.25064, Elapsed_time: 16757.27504
# Current_accuracy : 21.495, Current_norm_ED  : 0.8702
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# нергетическая ценность (калорийность) в ра | "ергетическая ценность (калорийность) в ра | 0.1586	False
# лактозы                   | лектозы                   | 0.9984	False
# --------------------------------------------------------------------------------
# validation time:  8.779607772827148
# training time:  111.54966068267822
# [28200/30000] Train loss: 0.00001, Valid loss: 1.27243, Elapsed_time: 16877.60431
# Current_accuracy : 21.963, Current_norm_ED  : 0.8729
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# тав свинина вода филе грулок кур б | тав: свинина вода филе грулок кур 6 " | 0.3554	False
# мононенасыщенные          | мононенасыщенные          | 0.6130	True
# --------------------------------------------------------------------------------
# validation time:  9.246561050415039
# training time:  106.6720941066742
# [28400/30000] Train loss: 0.00001, Valid loss: 1.26194, Elapsed_time: 16993.52296
# Current_accuracy : 21.963, Current_norm_ED  : 0.8711
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# портер- уполномоченыая организа | дордер - уолномоченная организа | 0.1686	False
# в какао масле             | в какао масле             | 0.4646	True
# --------------------------------------------------------------------------------
# validation time:  8.452351808547974
# training time:  111.5564546585083
# [28600/30000] Train loss: 0.00001, Valid loss: 1.25806, Elapsed_time: 17113.53177
# Current_accuracy : 21.963, Current_norm_ED  : 0.8707
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 899 ккал/                 | 899 ккал/                 | 0.9679	True
# "изготовитель: ооо ""парите " | изготовитель: ооо "парите | 0.1425	False
# --------------------------------------------------------------------------------
# validation time:  8.939425230026245
# training time:  111.61725640296936
# [28800/30000] Train loss: 0.00001, Valid loss: 1.28604, Elapsed_time: 17234.08845
# Current_accuracy : 21.495, Current_norm_ED  : 0.8706
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# хранить в сухом прохладном месте | хранить в сухом прохладном месте | 0.6971	True
# " бессоницей, артериальной гипертензией " | иеговиицей, артериальной гипертежзнв | 0.2143	False
# --------------------------------------------------------------------------------
# validation time:  8.506487846374512
# training time:  106.84343910217285
# [29000/30000] Train loss: 0.00001, Valid loss: 1.24533, Elapsed_time: 17349.43938
# Current_accuracy : 21.495, Current_norm_ED  : 0.8705
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "ная; д. 10, корп: 1, оф.425, тел: +7 (812) 346-60-02.гост р 52686 " | ная, д, 10, корп 1,оф. 425,тел. +7 (812) 346-60-02 гостр 52686 | 0.0036	False
# ищевая ценность в 100 продукт | ищевая ценность в 100 г продук | 0.2574	False
# --------------------------------------------------------------------------------
# validation time:  9.40926742553711
# training time:  111.75523042678833
# [29200/30000] Train loss: 0.00001, Valid loss: 1.27764, Elapsed_time: 17470.60488
# Current_accuracy : 21.963, Current_norm_ED  : 0.8709
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# консервы мясные кусковые стерилизованные | "онсервы мясные кусковые стерилизованные | 0.1255	False
# аурина                    | "она                      | 0.5316	False
# --------------------------------------------------------------------------------
# validation time:  9.77878189086914
# training time:  111.38744068145752
# [29400/30000] Train loss: 0.00001, Valid loss: 1.28604, Elapsed_time: 17591.77110
# Current_accuracy : 21.495, Current_norm_ED  : 0.8695
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# по россии звонок бесплатны | по россии звонок бесплатный | 0.9107	False
# хранить при температуре (4+2) с. | хранить при температуре (4+2'с | 0.1023	False
# --------------------------------------------------------------------------------
# validation time:  8.623713254928589
# training time:  106.94321060180664
# [29600/30000] Train loss: 0.00001, Valid loss: 1.27476, Elapsed_time: 17707.33802
# Current_accuracy : 21.495, Current_norm_ED  : 0.8707
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# масса нетто 125.          | масса нетто 125 г.        | 0.8472	False
# при от 0 до +6 с          | при от оло +6 с"          | 0.1830	False
# --------------------------------------------------------------------------------
# validation time:  8.19385838508606
# training time:  111.73795366287231
# [29800/30000] Train loss: 0.00001, Valid loss: 1.26883, Elapsed_time: 17827.26983
# Current_accuracy : 21.963, Current_norm_ED  : 0.8711
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# сливочный                 | ""сливочный>"             | 0.5950	False
# "изготовитель: ооо ""парите " | изготовитель: ооо "парите | 0.1382	False
# --------------------------------------------------------------------------------
# validation time:  8.202391624450684
# training time:  111.58625936508179
# [30000/30000] Train loss: 0.00001, Valid loss: 1.26761, Elapsed_time: 17947.05848
# Current_accuracy : 21.963, Current_norm_ED  : 0.8701
# Best_accuracy    : 23.364, Best_norm_ED     : 0.8743
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# " сти три-фосфат натрия, усипитель в " | сти три-фосфат натрия, усилитель в | 0.6531	False
# аровая камедь; регулятор кислотности-лимонная к: | "ровая камедь; регулятор кислотности лимонная к" | 0.0651	False
# --------------------------------------------------------------------------------
# validation time:  8.49467921257019
# end the training
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# c:\anaconda\envs\pytorch-gpu-python-3-10\lib\site-packages\IPython\core\interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
